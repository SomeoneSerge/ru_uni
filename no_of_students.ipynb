# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import requests
import contextlib
import functools
import itertools
import collections
import pprint
import glob

plt.ion()

# %%
example_xls = 'Своды ВПО-1 2018/Государственные/Воронежская область_ГОС_очная.xls'

# %%
import xlrd

# %%
ex = xlrd.open_workbook(example_xls)

# %%
ex.sheet_names()
# Out:
# ['Р1_1',
#  'P1_2(1)',
#  'P1_2(2)',
#  'Р2_1_1',
#  'Р2_1_2(1)',
#  'Р2_1_2 (2)',
#  'Р2_1_2 (3)',
#  'Р2_1_2 (4)',
#  'Р2_1_3(1)',
#  'Р2_1_3(2)',
#  'Р2_1_4',
#  'Р2_1_5 (1)',
#  'Р2_1_5 (2)',
#  'Р2_1_6',
#  'Р2_2',
#  'Р2_3',
#  'Р2_4',
#  'Р2_5',
#  'Р2_6',
#  'Р2_7',
#  'Р2_8',
#  'Р2_9',
#  'Р2_10',
#  'Р2_11(1)',
#  'P2_11(2)',
#  'Р2_12(1)',
#  'Р2_12(2)',
#  'Р2_12(3)',
#  'Р2_13',
#  'Р3_1',
#  'P3_2',
#  'Р3_3_1',
#  'P3_3_2',
#  'P3_4',
#  'P3_5',
#  'P3_6',
#  'P3_7_1',
#  'P3_7_2']

# %%
grad_sheet = ex.sheet_by_name('Р2_1_3(1)')

# %%
list(itertools.islice(grad_sheet.get_rows(), 50))
# Out:
# [[text:'Воронежская область',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:''],
#  [text:'Государственные, Муниципальные',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:''],
#  [text:'очная',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:''],
#  [text:'2.1.3. Распределение выпуска бакалавров, специалистов, магистров по направлениям подготовки и специальностям',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:''],
#  [text:'Коды по ОКЕИ: человек - 792',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:''],
#  [text:'Наименование \nнаправления подготовки (специальности)',
#   text:'№ строки',
#   text:'Код классифи-катора',
#   text:'Код направле-ния подготов-ки (специаль-ности)',
#   text:'Выпуск фактический с 01.10. прошлого года по 30.09. текущего года',
#   empty:'',
#   text:'В том числе (из гр.5)',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'Из общего выпуска',
#   empty:''],
#  [empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'всего (сумма гр. 10, 12, 13, 15)',
#   text:'из них лица с ОВЗ, инвалиды, дети-инвалиды',
#   text:'продолжили обучение по программам',
#   empty:'',
#   empty:'',
#   text:'обучались',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'женщины',
#   text:'выпуск из числа студентов, принятых не на условиях целевого приема, заключивших договор о целевом обучении (кроме учтенных в гр. 14)'],
#  [empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'бакалав-риата',
#   text:'специали-тета',
#   text:'магистра-туры',
#   text:'за счет бюджетных ассигнований',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'по договорам об оказании платных образова-тельных услуг',
#   empty:'',
#   empty:''],
#  [empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'федерального бюджета',
#   empty:'',
#   text:'бюджета субъекта Российской Федерации',
#   text:'местного бюджета',
#   text:'из суммы гр. 10, 12, 13 - поступившие в рамках квоты целевого приема ',
#   empty:'',
#   empty:'',
#   empty:''],
#  [empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   text:'всего',
#   text:'из них лица с ОВЗ, инвалиды, дети-инвалиды',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:'',
#   empty:''],
#  [number:1.0,
#   number:2.0,
#   number:3.0,
#   number:4.0,
#   number:5.0,
#   number:6.0,
#   number:7.0,
#   number:8.0,
#   number:9.0,
#   number:10.0,
#   number:11.0,
#   number:12.0,
#   number:13.0,
#   number:14.0,
#   number:15.0,
#   number:16.0,
#   number:17.0],
#  [text:'Программы бакалавриата - всего',
#   number:1.0,
#   number:0.0,
#   number:0.0,
#   number:6940.0,
#   number:42.0,
#   number:17.0,
#   number:0.0,
#   number:2691.0,
#   number:4417.0,
#   number:37.0,
#   number:0.0,
#   number:2.0,
#   number:517.0,
#   number:2521.0,
#   number:4076.0,
#   number:4.0],
#  [text:'Математика',
#   number:1.0,
#   number:1.0,
#   text:'01.03.01',
#   number:25.0,
#   number:1.0,
#   number:0.0,
#   number:0.0,
#   number:20.0,
#   number:23.0,
#   number:1.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:2.0,
#   number:11.0,
#   number:0.0],
#  [text:'Прикладная математика и информатика',
#   number:1.0,
#   number:1.0,
#   text:'01.03.02',
#   number:79.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:62.0,
#   number:77.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:1.0,
#   number:2.0,
#   number:31.0,
#   number:0.0],
#  [text:'Механика и математическое моделирование',
#   number:1.0,
#   number:1.0,
#   text:'01.03.03',
#   number:18.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:14.0,
#   number:18.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:7.0,
#   number:0.0],
#  [text:'Прикладная математика',
#   number:1.0,
#   number:1.0,
#   text:'01.03.04',
#   number:14.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:7.0,
#   number:13.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:1.0,
#   number:8.0,
#   number:0.0],
#  [text:'Математика и компьютерные науки',
#   number:1.0,
#   number:1.0,
#   text:'02.03.01',
#   number:57.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:39.0,
#   number:48.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:1.0,
#   number:9.0,
#   number:29.0,
#   number:0.0],
#  [text:'Фундаментальная информатика и информационные технологии',
#   number:1.0,
#   number:1.0,
#   text:'02.03.02',
#   number:26.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:19.0,
#   number:21.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:5.0,
#   number:6.0,
#   number:0.0],
#  [text:'Математическое обеспечение и администрирование информационных систем',
#   number:1.0,
#   number:1.0,
#   text:'02.03.03',
#   number:37.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:22.0,
#   number:30.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:7.0,
#   number:14.0,
#   number:0.0],
#  [text:'Физика',
#   number:1.0,
#   number:1.0,
#   text:'03.03.02',
#   number:59.0,
#   number:0.0,
#   number:1.0,
#   number:0.0,
#   number:41.0,
#   number:59.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:30.0,
#   number:0.0],
#  [text:'Радиофизика',
#   number:1.0,
#   number:1.0,
#   text:'03.03.03',
#   number:56.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:44.0,
#   number:56.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:13.0,
#   number:0.0],
#  [text:'Химия',
#   number:1.0,
#   number:1.0,
#   text:'04.03.01',
#   number:47.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:34.0,
#   number:41.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:6.0,
#   number:32.0,
#   number:0.0],
#  [text:'Химия, физика и механика материалов',
#   number:1.0,
#   number:1.0,
#   text:'04.03.02',
#   number:19.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:6.0,
#   number:19.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:14.0,
#   number:0.0],
#  [text:'Геология',
#   number:1.0,
#   number:1.0,
#   text:'05.03.01',
#   number:68.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:46.0,
#   number:66.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:5.0,
#   number:2.0,
#   number:24.0,
#   number:0.0],
#  [text:'География',
#   number:1.0,
#   number:1.0,
#   text:'05.03.02',
#   number:39.0,
#   number:0.0,
#   number:1.0,
#   number:0.0,
#   number:16.0,
#   number:39.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:28.0,
#   number:0.0],
#  [text:'Экология и природопользование',
#   number:1.0,
#   number:1.0,
#   text:'05.03.06',
#   number:75.0,
#   number:1.0,
#   number:1.0,
#   number:0.0,
#   number:33.0,
#   number:71.0,
#   number:1.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:45.0,
#   number:0.0],
#  [text:'Биология',
#   number:1.0,
#   number:1.0,
#   text:'06.03.01',
#   number:70.0,
#   number:3.0,
#   number:0.0,
#   number:0.0,
#   number:43.0,
#   number:69.0,
#   number:3.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:1.0,
#   number:61.0,
#   number:0.0],
#  [text:'Почвоведение',
#   number:1.0,
#   number:1.0,
#   text:'06.03.02',
#   number:19.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:10.0,
#   number:19.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:16.0,
#   number:0.0],
#  [text:'Архитектура',
#   number:1.0,
#   number:1.0,
#   text:'07.03.01',
#   number:55.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:34.0,
#   number:52.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:18.0,
#   number:3.0,
#   number:45.0,
#   number:0.0],
#  [text:'Реконструкция и реставрация архитектурного наследия',
#   number:1.0,
#   number:1.0,
#   text:'07.03.02',
#   number:27.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:13.0,
#   number:22.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:9.0,
#   number:5.0,
#   number:21.0,
#   number:0.0],
#  [text:'Дизайн архитектурной среды',
#   number:1.0,
#   number:1.0,
#   text:'07.03.03',
#   number:26.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:7.0,
#   number:24.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:7.0,
#   number:2.0,
#   number:24.0,
#   number:0.0],
#  [text:'Градостроительство',
#   number:1.0,
#   number:1.0,
#   text:'07.03.04',
#   number:34.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:26.0,
#   number:34.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:8.0,
#   number:0.0,
#   number:23.0,
#   number:0.0],
#  [text:'Строительство',
#   number:1.0,
#   number:1.0,
#   text:'08.03.01',
#   number:453.0,
#   number:3.0,
#   number:0.0,
#   number:0.0,
#   number:278.0,
#   number:413.0,
#   number:3.0,
#   number:0.0,
#   number:0.0,
#   number:116.0,
#   number:40.0,
#   number:184.0,
#   number:0.0],
#  [text:'Информатика и вычислительная техника',
#   number:1.0,
#   number:1.0,
#   text:'09.03.01',
#   number:49.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:17.0,
#   number:47.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:2.0,
#   number:7.0,
#   number:0.0],
#  [text:'Информационные системы и технологии',
#   number:1.0,
#   number:1.0,
#   text:'09.03.02',
#   number:200.0,
#   number:2.0,
#   number:0.0,
#   number:0.0,
#   number:103.0,
#   number:156.0,
#   number:2.0,
#   number:0.0,
#   number:0.0,
#   number:8.0,
#   number:44.0,
#   number:43.0,
#   number:0.0],
#  [text:'Прикладная информатика',
#   number:1.0,
#   number:1.0,
#   text:'09.03.03',
#   number:77.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:28.0,
#   number:55.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:22.0,
#   number:36.0,
#   number:0.0],
#  [text:'Программная инженерия',
#   number:1.0,
#   number:1.0,
#   text:'09.03.04',
#   number:9.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:8.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:1.0,
#   number:1.0,
#   number:0.0],
#  [text:'Радиотехника',
#   number:1.0,
#   number:1.0,
#   text:'11.03.01',
#   number:28.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:28.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:3.0,
#   number:0.0,
#   number:3.0,
#   number:0.0],
#  [text:'Конструирование и технология электронных средств',
#   number:1.0,
#   number:1.0,
#   text:'11.03.03',
#   number:49.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:11.0,
#   number:49.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:7.0,
#   number:0.0,
#   number:8.0,
#   number:0.0],
#  [text:'Электроника и наноэлектроника',
#   number:1.0,
#   number:1.0,
#   text:'11.03.04',
#   number:36.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:11.0,
#   number:36.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:1.0,
#   number:0.0,
#   number:8.0,
#   number:0.0],
#  [text:'Приборостроение',
#   number:1.0,
#   number:1.0,
#   text:'12.03.01',
#   number:13.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:6.0,
#   number:13.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:2.0,
#   number:0.0],
#  [text:'Фотоника и оптоинформатика',
#   number:1.0,
#   number:1.0,
#   text:'12.03.03',
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0],
#  [text:'Биотехнические системы и технологии',
#   number:1.0,
#   number:1.0,
#   text:'12.03.04',
#   number:30.0,
#   number:1.0,
#   number:0.0,
#   number:0.0,
#   number:20.0,
#   number:30.0,
#   number:1.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:17.0,
#   number:0.0],
#  [text:'Теплоэнергетика и теплотехника',
#   number:1.0,
#   number:1.0,
#   text:'13.03.01',
#   number:51.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:32.0,
#   number:50.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:9.0,
#   number:1.0,
#   number:8.0,
#   number:0.0],
#  [text:'Электроэнергетика и электротехника',
#   number:1.0,
#   number:1.0,
#   text:'13.03.02',
#   number:41.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:22.0,
#   number:41.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:6.0,
#   number:0.0,
#   number:6.0,
#   number:0.0],
#  [text:'Ядерная энергетика и теплофизика',
#   number:1.0,
#   number:1.0,
#   text:'14.03.01',
#   number:12.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:10.0,
#   number:12.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:3.0,
#   number:0.0],
#  [text:'Машиностроение',
#   number:1.0,
#   number:1.0,
#   text:'15.03.01',
#   number:28.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:24.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:5.0,
#   number:4.0,
#   number:5.0,
#   number:0.0],
#  [text:'Технологические машины и оборудование',
#   number:1.0,
#   number:1.0,
#   text:'15.03.02',
#   number:98.0,
#   number:3.0,
#   number:0.0,
#   number:0.0,
#   number:37.0,
#   number:96.0,
#   number:3.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:2.0,
#   number:20.0,
#   number:0.0],
#  [text:'Прикладная механика',
#   number:1.0,
#   number:1.0,
#   text:'15.03.03',
#   number:9.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:4.0,
#   number:9.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:2.0,
#   number:0.0],
#  [text:'Автоматизация технологических процессов и производств',
#   number:1.0,
#   number:1.0,
#   text:'15.03.04',
#   number:45.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:21.0,
#   number:45.0,
#   number:0.0,
#   number:0.0,
#   number:0.0,
#   number:3.0,
#   number:0.0,
#   number:7.0,
#   number:0.0]]

# %%
sheet = ex.sheets()[0]
sheet.name
# Out:
# 'Р1_1'

# %%
number_example = next(itertools.islice(grad_sheet.get_rows(), 50, 51))[1]
print(number_example)
print(number_example.value)
print(number_example.ctype)
# Out:
# number:1.0
# 1.0
# 2

# %%
empty_example = next(r for r in grad_sheet.get_rows())[-1]
print(empty_example)
print(repr(empty_example.value))
print(empty_example.ctype)
# Out:
# empty:''
# ''
# 0

# %% [markdown]
# So, one task for tomorrow is to write a VPO-1 reader
#
# - [ ] `VPO1Reader`, handles a single `.xls` file.
#     Possible solution:
#     - [x] Table's header
#         - [x] Get the number of columns
#         - [x] Find the separator between the header and the numbers
#         - [x] For each row above separator, enumerate its cells, accumulating the "atomic column"'s name
#     - [x] Data: traverse rows below separator, appending values into vectors of appropriate "atomic column"s
# - [x] `VPOSet`, handles the folder with region-wise reports
# - [ ] Download function

# %%
import xlrd
import re
import typing


# STARTSWITH_UNITS = 'коды по океи: '
            
class VPO1ParsingError(Exception):
    pass

class VPO1Row:
    def __init__(self, cells):
        # consider, for `str`s:
        # cells = map(str.strip, cells)
        # cells = map(str.lower, cells)
        # plus multiple spaces, etc
        cells = list(cells)
        self.cells = cells
        self.atomic_to_full = [i if c is not None else None for i, c in enumerate(cells)]
        self.atomic_to_full[0] = 0
        self._n_cells = sum(map(lambda x: x is not None, self.atomic_to_full))
        for i, ref in enumerate(self.atomic_to_full):
            if ref is None:
                self.atomic_to_full[i] = self.atomic_to_full[i - 1]
        for ref in self.atomic_to_full:
            assert ref is not None
    @property
    def n_cells(self):
        return self._n_cells
    @property
    def n_atomic_cells(self):
        return len(self.cells)
    def clone(self):
        return VPO1Row(self.cells)
    def __getitem__(self, atomic_cell_id):
        cell_id = self.atomic_to_full[atomic_cell_id]
        return self.cells[cell_id]
    def __setitem__(self, atomic_cell_id, value):
        cell_id = self.atomic_to_full[atomic_cell_id]
        self.cells[cell_id] = value
    def __repr__(self):
        return repr(self.cells)
    
class VPO1Header:
    DESC = ['region', 'is_governmental', 'fulltime', 'section_name', 'units']
    DESC = dict(((x, i) for i, x in enumerate(DESC)))
    def __init__(self, rows: typing.List[VPO1Row], n_cols: int):
        
        if len(rows) < len(VPO1Header.DESC):
            raise VPO1ParsingError(
                'Expected at least {} rows in the header (for the traits) got {}'
                .format(len(rows, len(VPO1Header.DESC)))
            )
        if not isinstance(rows[VPO1Header.DESC['units']][0], str):
            raise VPO1ParsingError('Units of measurement misspecified')
        if not 'ОКЕИ' in rows[VPO1Header.DESC['units']][0]:
            raise VPO1ParsingError('Units of measurement misspecified')
        
        
        TRANSFORMS = collections.defaultdict(lambda: (lambda x: x))
        # TRANSFORMS['units'] = lambda x: x.replace(STARTSWITH_UNITS, '')
        for field, i in VPO1Header.DESC.items():
            transform = TRANSFORMS[field]
            setattr(self, field, transform(rows[i][0]))
        
        def table_header_transform(x):
            if x is None:
                return ''
            return str(x)
        table_header_start = len(VPO1Header.DESC) + 1
        table_header = (
            (row[i] for row in rows[table_header_start:])
            for i in range(n_cols)
        )
        table_header = [' '.join(map(table_header_transform, col)) for col in table_header]
        self.table_header = table_header
        self.n_cols = n_cols
        
def vpo1_table(header: VPO1Header,
               rows: typing.List[VPO1Row]) -> pd.DataFrame:
    index = [row[0] for row in rows]
    cols = header.table_header[1: ]
    data = data=[[row[i] for i in range(1, header.n_cols)] for row in rows]
    df = pd.DataFrame(data=data,
                      index=index,
                      columns=cols)
    return df

class VPO1Page:
    def __init__(self, rows: typing.List[VPO1Row]):
        try:
            idx_col_numbers = next(i for i, x in enumerate(rows)
                                   if isinstance(x[0], float) and x[0] == 1)
        except StopIteration:
            raise VPO1ParsingError('Invalid sheet. You probably should just skip it.')
        n_cols = max(map(lambda r: r.n_cells, rows))
        self.header = VPO1Header(rows[:idx_col_numbers], n_cols)
        self.table = vpo1_table(self.header, rows[idx_col_numbers + 1: ])
        for field in VPO1Header.DESC:
            setattr(self, field, getattr(self.header, field))
    @staticmethod
    def try_yield_parsed(rows):
        try:
            yield VPO1Page(rows)
        except VPO1ParsingError:
            pass

    
class VPO1:
    def __init__(self, sheets: typing.Dict[str, typing.List[VPO1Row]]):
        # pages = map(lambda name, rows: zip([name], VPO1Page.try_yield_parsed(rows)), sheets.items())
        pages = (list(zip([name], VPO1Page.try_yield_parsed(rows))) for name, rows in sheets.items())
        pages = itertools.chain.from_iterable(pages)
        pages = list(pages)
        self.names, self.pages = [n for n, p in pages], [p for n, p in pages]
        if len(self.pages) == 0:
            raise VPO1ParsingError('No pages could be parsed')
        page0 = self.pages[0]
        for field in VPO1Header.DESC:
            setattr(self, field, getattr(page0, field))
    @staticmethod
    def try_yield_parsed(sheets):
        try:
            yield VPO1(sheets)
        except VPO1ParsingError:
            pass
def unpack_cell(cell):
    # TODO: apply normalization, stripping str's, etc -- right here
    return cell.value if cell.ctype != 0 else None

def unpack_row(row):
    return map(unpack_cell, row)

def read_vpo1(filename):
    xls = xlrd.open_workbook(filename)
    vpo1 = dict((s.name, list(map(VPO1Row,
                                  map(unpack_row, s.get_rows()))))
                for s in xls.sheets())
    vpo1 = VPO1(vpo1)
    return vpo1


class VPO1Set:
    def _init_deep_inspect(self, path):
        self.files = (
            glob.glob(os.path.join(path, 'СВОД_ВПО1*.xls'))
            + glob.glob(os.path.join(path, 'Своды ВПО-1*/*/*.xls')))
        self.file_to_i = dict((f, i) for i, f in enumerate(self.files))
        self.file_to_traits = list()
        for f in self.files:
            # TODO: use iterables, not lists; read only header; don't create pd.DataFrame yet;
            # NB: splitting names would've been faster but I'm rather hesitant to bind to them
            #     as they might be unstable;
            vpo1 = read_vpo1(f).pages[0].header
            # TODO: namedtuple
            self.file_to_traits.append(dict((field, getattr(vpo1, field)) for field in VPO1Header.DESC))
    def _init_name_inspect(self, path):
        for root, dirs, files in os.walk(path):
            files = ((split(f) for split in [self.split_name_country, self.split_name_region])
                     for f in files)
            files = (itertools.islice((splitted for splitted in f if splitted is not None), 0, 1)
                     for f in files)
            files = itertools.chain.from_iterable(files)
            files = list(files)
            for filename, traits in files:
                self.files.append(filename)
                self.file_to_traits.append(traits)
    @staticmethod
    def split_name_country(s):
        PAT_COUNTRY = re.compile(r'СВОД_ВПО1_(?P<is_governmental>[А-Я]+)_(?P<fulltime>[А-Яа-я\s-]+)\.xls')
        m = PAT_COUNTRY.match(s)
        if not m:
            return None
        return (s, dict(region='Russia',
                    is_governmental=m.group('is_governmental'),
                    fulltime=m.group('fulltime')))
    @staticmethod
    def split_name_region(s):
        PAT_REGION = re.compile(r'(?P<region>[а-яА-Я\s-]+)_(?P<is_governmental>[А-Я]+)_(?P<fulltime>[а-яА-Я\s-]+)\.xls')
        m = PAT_REGION.match(s)
        if not m:
            return None
        return (s, dict(m.groupdict()))
    def __init__(self, path, deep=False):
        self.files = []
        self.file_to_traits = []
        if deep:
            self._init_deep_inspect(path)
        else:
            self._init_name_inspect(path)
        VPO1SET_TRAITS = ['region', 'is_governmental', 'fulltime']
        for field in VPO1SET_TRAITS:
            setattr(self, field + 's', list(set(map(lambda x: x[field], self.file_to_traits))))
                    
                
    def get_vpo1(region, is_governmental, fulltime):
        return next(x for x, traits in self.file_to_traits
                    if region == traits['region']
                       and is_governmental == traits['is_governmental']
                       and fulltime == traits['fulltime'])

# %%
import unittest


class VPO1AssumptionsTest(unittest.TestCase):
    def test_sheet_grad(self):
        filename = 'Своды ВПО-1 2018/Государственные/Воронежская область_ГОС_очная.xls'
        sheetname = 'Р2_1_2 (4)'
        xls = xlrd.open_workbook(filename)
        sheet = xls.sheet_by_name(sheetname)
        vpo1page = list(map(VPO1Row, map(unpack_row, sheet.get_rows())))
        vpo1page = VPO1Page(vpo1page)

    def test_read_vpo1(self):
        vpo1 = read_vpo1('Своды ВПО-1 2018/Государственные/Воронежская область_ГОС_очная.xls')
        self.assertEqual(vpo1.region, 'Воронежская область')
        self.assertEqual(vpo1.fulltime, 'очная')
    def test_vpo1set_nonempty(self):
        vpo1set = VPO1Set('.')
        assert len(vpo1set.files) > 0
        

suite = unittest.TestLoader().loadTestsFromTestCase(VPO1AssumptionsTest)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_read_vpo1 (__main__.VPO1AssumptionsTest) ... ok
# test_sheet_grad (__main__.VPO1AssumptionsTest) ... ok
# test_vpo1set_nonempty (__main__.VPO1AssumptionsTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.704s
#
# OK
# <unittest.runner.TextTestResult run=3 errors=0 failures=0>

# %%
filename = 'Своды ВПО-1 2018/Государственные/Воронежская область_ГОС_очная.xls'
vpo1 = read_vpo1(filename)

# %%
vpo1.region, vpo1.fulltime, vpo1.is_governmental
# Out:
# ('Воронежская область', 'очная', 'Государственные, Муниципальные')

# %%
vpo1.pages[2].section_name
# Out:
# '2.1.2. Распределение численности студентов по курсам, направлениям подготовки и специальностям'

# %%
vpo1.pages[2].table
# Out:
#                                                                         \
# Программы бакалавриата - всего                      1.0  0.0         0
# Математика                                          1.0  1.0  01.03.01
# Прикладная математика и информатика                 1.0  1.0  01.03.02
# Механика и математическое моделирование             1.0  1.0  01.03.03
# Прикладная математика                               1.0  1.0  01.03.04
# Математика и компьютерные науки                     1.0  1.0  02.03.01
# Фундаментальная информатика и информационные те...  1.0  1.0  02.03.02
# Математическое обеспечение и администрирование ...  1.0  1.0  02.03.03
# Физика                                              1.0  1.0  03.03.02
# Радиофизика                                         1.0  1.0  03.03.03
# Химия                                               1.0  1.0  04.03.01
# Химия, физика и механика материалов                 1.0  1.0  04.03.02
# Геология                                            1.0  1.0  05.03.01
# География                                           1.0  1.0  05.03.02
# Экология и природопользование                       1.0  1.0  05.03.06
# Биология                                            1.0  1.0  06.03.01
# Почвоведение                                        1.0  1.0  06.03.02
# Архитектура                                         1.0  1.0  07.03.01
# Реконструкция и реставрация архитектурного насл...  1.0  1.0  07.03.02
# Дизайн архитектурной среды                          1.0  1.0  07.03.03
# Градостроительство                                  1.0  1.0  07.03.04
# Строительство                                       1.0  1.0  08.03.01
# Информатика и вычислительная техника                1.0  1.0  09.03.01
# Информационные системы и технологии                 1.0  1.0  09.03.02
# Прикладная информатика                              1.0  1.0  09.03.03
# Программная инженерия                               1.0  1.0  09.03.04
# Информационная безопасность                         1.0  1.0  10.03.01
# Радиотехника                                        1.0  1.0  11.03.01
# Конструирование и технология электронных средств    1.0  1.0  11.03.03
# Электроника и наноэлектроника                       1.0  1.0  11.03.04
# ...                                                 ...  ...       ...
# Агрохимия и агропочвоведение                        3.0  1.0  35.04.03
# Агрономия                                           3.0  1.0  35.04.04
# Садоводство                                         3.0  1.0  35.04.05
# Агроинженерия                                       3.0  1.0  35.04.06
# Ландшафтная архитектура                             3.0  1.0  35.04.09
# Зоотехния                                           3.0  1.0  36.04.02
# Психология                                          3.0  1.0  37.04.01
# Экономика                                           3.0  1.0  38.04.01
# Менеджмент                                          3.0  1.0  38.04.02
# Государственное и муниципальное управление          3.0  1.0  38.04.04
# Товароведение                                       3.0  1.0  38.04.07
# Финансы и кредит                                    3.0  1.0  38.04.08
# Юриспруденция                                       3.0  1.0  40.04.01
# Зарубежное регионоведение                           3.0  1.0  41.04.01
# Политология                                         3.0  1.0  41.04.04
# Международные отношения                             3.0  1.0  41.04.05
# Реклама и связи с общественностью                   3.0  1.0  42.04.01
# Журналистика                                        3.0  1.0  42.04.02
# Издательское дело                                   3.0  1.0  42.04.03
# Сервис                                              3.0  1.0  43.04.01
# Педагогическое образование                          3.0  1.0  44.04.01
# Психолого-педагогическое образование                3.0  1.0  44.04.02
# Филология                                           3.0  1.0  45.04.01
# Лингвистика                                         3.0  1.0  45.04.02
# История                                             3.0  1.0  46.04.01
# Философия                                           3.0  1.0  47.04.01
# Всего по программам бакалавриата, специалитета ...  4.0  0.0         0
# Обучаются второй год на данном курсе, включая н...  5.0  0.0         0
# Обучаются второй год на данном курсе, включая н...  6.0  0.0         0
# Обучаются второй год на данном курсе, включая н...  7.0  0.0         0
#
#                                                     всего (сумма гр.7, 9–11)    \
# Программы бакалавриата - всего                                          8306.0
# Математика                                                                27.0
# Прикладная математика и информатика                                      123.0
# Механика и математическое моделирование                                   32.0
# Прикладная математика                                                     34.0
# Математика и компьютерные науки                                           95.0
# Фундаментальная информатика и информационные те...                        52.0
# Математическое обеспечение и администрирование ...                        45.0
# Физика                                                                    61.0
# Радиофизика                                                               82.0
# Химия                                                                     47.0
# Химия, физика и механика материалов                                       22.0
# Геология                                                                 113.0
# География                                                                 46.0
# Экология и природопользование                                            105.0
# Биология                                                                  91.0
# Почвоведение                                                              15.0
# Архитектура                                                               59.0
# Реконструкция и реставрация архитектурного насл...                        34.0
# Дизайн архитектурной среды                                                53.0
# Градостроительство                                                        45.0
# Строительство                                                            423.0
# Информатика и вычислительная техника                                      91.0
# Информационные системы и технологии                                      324.0
# Прикладная информатика                                                   161.0
# Программная инженерия                                                     34.0
# Информационная безопасность                                               13.0
# Радиотехника                                                              46.0
# Математика и компьютерные науки                                                                   1.0
# Фундаментальная информатика и информационные те...                                                0.0
# Математическое обеспечение и администрирование ...                                                2.0
# Физика                                                                                            0.0
# Радиофизика                                                                                       1.0
# Химия                                                                                             0.0
# Химия, физика и механика материалов                                                               0.0
# Геология                                                                                          3.0
# География                                                                                         0.0
# Экология и природопользование                                                                     1.0
# Биология                                                                                          2.0
# Почвоведение                                                                                      0.0
# Архитектура                                                                                       1.0
# Реконструкция и реставрация архитектурного насл...                                                0.0
# Дизайн архитектурной среды                                                                        0.0
# Градостроительство                                                                                1.0
# Строительство                                                                                     4.0
# Информатика и вычислительная техника                                                              1.0
# Информационные системы и технологии                                                               2.0
# Прикладная информатика                                                                            1.0
# Программная инженерия                                                                             2.0
# Информационная безопасность                                                                       0.0
# Радиотехника                                                                                      1.0
# Конструирование и технология электронных средств                                                  0.0
# Электроника и наноэлектроника                                                                     0.0
# ...                                                                                               ...
# Агрохимия и агропочвоведение                                                                      0.0
# Агрономия                                                                                         0.0
# Садоводство                                                                                       0.0
# Агроинженерия                                                                                     0.0
# Ландшафтная архитектура                                                                           0.0
# Зоотехния                                                                                         1.0
# Психология                                                                                        1.0
# Экономика                                                                                         0.0
# Менеджмент                                                                                        0.0
# Государственное и муниципальное управление                                                        0.0
# Товароведение                                                                                     0.0
# Финансы и кредит                                                                                  0.0
# Юриспруденция                                                                                     0.0
# Зарубежное регионоведение                                                                         0.0
# Политология                                                                                       0.0
# Международные отношения                                                                           0.0
# Реклама и связи с общественностью                                                                 1.0
# Журналистика                                                                                      0.0
# Издательское дело                                                                                 0.0
# Сервис                                                                                            1.0
# Педагогическое образование                                                                        1.0
# Психолого-педагогическое образование                                                              0.0
# Филология                                                                                         0.0
# Лингвистика                                                                                       0.0
# История                                                                                           0.0
# Философия                                                                                         0.0
# Всего по программам бакалавриата, специалитета ...                                              114.0
# Обучаются второй год на данном курсе, включая н...                                                0.0
# Обучаются второй год на данном курсе, включая н...                                                0.0
# Обучаются второй год на данном курсе, включая н...                                                0.0
#
#                                                     за счет бюджетных ассигнований бюджета субъекта Российской Федерации из них лица с ОВЗ, инвалиды, дети-инвалиды  \
# Программы бакалавриата - всего                                                                    0.0
# Математика                                                                                        0.0
# Прикладная математика и информатика                                                               0.0
# Механика и математическое моделирование                                                           0.0
# Прикладная математика                                                                             0.0
# Математика и компьютерные науки                                                                   0.0
# Фундаментальная информатика и информационные те...                                                0.0
# Математическое обеспечение и администрирование ...                                                0.0
# Физика                                                                                            0.0
# Радиофизика                                                                                       0.0
# Химия                                                                                             0.0
# Химия, физика и механика материалов                                                               0.0
# Геология                                                                                          0.0
# География                                                                                         0.0
# Экология и природопользование                                                                     0.0
# Биология                                                                                          0.0
# Почвоведение                                                                                      0.0
# Архитектура                                                                                       0.0
# Реконструкция и реставрация архитектурного насл...                                                0.0
# Дизайн архитектурной среды                                                                        0.0
# Градостроительство                                                                                0.0
# Строительство                                                                                     0.0
# Информатика и вычислительная техника                                                              0.0
# Информационные системы и технологии                                                               0.0
# Прикладная информатика                                                                            0.0
# Программная инженерия                                                                             0.0
# Информационная безопасность                                                                       0.0
# Радиотехника                                                                                      0.0
